# %% [markdown]
# # CS51 Assignment 2: Algorithms and Simulation
#
#
# This assignment has two distinct parts in addition to a reflection: Part 1 requires you to apply your knowledge of algorithmic thinking and optimization and Part 2 allows you to demonstrate your modeling and coding skills by writing a numerical simulation. Material relevant for Part 1 will be covered in class during weeks 3-5, while material relevant for Part 2 will be covered in class during weeks 7 and 8.
#
#
# You'll notice several "*Optional Challenge*" problems throughout the assignment to challenge yourself. These will only be scored (4 or 5) if they are completed correctly with thorough explanation. If you attempt an optional challenge but do not succeed, you will not be penalized with a low score. Remember that you must include an explanation and interpretation for optional problems to be scored.
#
#
# *This is an individual assignment. We will be checking for similarities among submissions and will take plagiarism seriously*.
#
#
# **You must complete all tasks within this pre-formatted Jupyter notebook. Please follow ALL formatting guidelines and the HC Guidelines in the assignment instructions on Forum (near the top and bottom of the instructions respectively).**

# %% [markdown]
# ## **PART 1: OPTIMIZATION**
#
# For this section of the assignment, you will select one of the scenarios below and apply #optimization. You must complete all sections. [#optimization, potentially relevant: #modeling, #algorithms, #variables, #utility, #constraints]
#
# 1. *Scenario 1*: To prevent the spread of an infectious disease, a vaccine needs to be distributed as quickly and efficiently as possible to the 15 cities that have had major outbreaks. How can you optimize the route between the cities? For this scenario, you should select cities that are relevant to the disease that you will choose for PART 2 and include a map of these cities (you may use an existing map or draw your own).
#
#
# 2. *Scenario 2*: Suppose that a new virus is starting to spread, and many clinics do not have sophisticated diagnostic tools and must be able to determine whether or not a patient has this dangerous virus based solely on easily measured symptoms. You have been collecting information on symptoms (temperature, WBC count, headache severity, and cough severity) and you need to determine which patients have this new disease and which have only a milder illness. Plots that provide an overview of the data are available [here](https://drive.google.com/file/d/1td_jCTzYiOCMPJ8CwVSJU7u-pQ-5R1JW/view?usp=sharing). The data can be accessed at [this link](https://drive.google.com/file/d/1smz8OhVkIAbWVKpmkx7liE3bOWLfQch7/view?usp=sharing) (1 = Infected, 0 = Not infected).
#
# #### 1.1 Optimization Problem:
# Describe the optimization problem for your scenario: what is the objective function? What are the decision variables? Are there any constraints? Clearly articulate each component so that it’s clear how the objective function would be measured and how the decision variables would impact it (~200 words).

# %% [markdown]
# The objective function in this case is to maximise the testing data accuracy; to minimise the number of individuals misclassified as infected or not infected based on their symptoms. This can be measured using testing data, which will determine the accuracy of the classifier. The decision variable in this case is the choice of algorithm to find an optimal solution to the problem. Different algorithms can provide different advantages in terms of computational power, ease of implementation, global optimisation, and accounting for overfitting and other constraints. These factors impact the optimisation of predictions.
#
# Only 100 data points can be used in the model, potentially leading to the misclassification of points when the model is used in reality, as this is a very small sample of the total population of individuals who have experienced the disease, and therefore we could improve the model through increasing the volume of data used.
#
# Another constraint on the optimisation of the problem is the potential for overfitting. Given that there is a fair amount of overlap in the distributions of the data given, it will become difficult in most cases to seperate the data into the two groups: infected and not infected. Consequently, it is difficult to find a classification algorithm that will optimise for training data without becoming overfitting by creating a classifier that is based too heavily on the training data. This overfitting can lead to a suboptimal solution in reality, as the classification will not be representative for future predictions.

# %% [markdown]
# #### 1.2 Optimization Technique:
#
# What process can be used to find the optimal solution in your scenario? Identify and describe an existing algorithm that could be used to complete this process, including the inputs, outputs, and required steps. Explain the advantages and limitations of this algorithm. In your explanation, you should address whether your algorithm would lead to the global optimum and you may wish to compare your algorithm with other possible optimization techniques. (~200 words)
#
# - *Optional*: Draw a flowchart to illustrate the process.
#
# - *Optional*: Create a program in python to implement this optimization process.

# %% [markdown]
# In order to diagnose individuals, a decision tree can be used. We can also define this optimisation problem, with the objective function being the maximisation of the number of correctly classified indiviudals, and the decision variables the depth of the classification tree, the number of nodes from each decision node in the tree, the number of leaf nodes, as well as the predictor variables included in the model: the white blood cell count of the individual, their temperature, cough severity, and headache severity. Varying combinations of these variables can be used to optimise the predictions of the problem. In this case, the distributions of the variables allow us to use all the predictors to create a classification algorithm (Assignment Data Scatter Plot Matrix.png, 2021). The cough severity, however, should not be considered too heavily, as the two data groups are fairly inseperable, as you can see by the strong overlap in data (Assignment Data Scatter Plot Matrix.png, 2021). Consequently, the below decision tree does not seperate the data based on this variable.
#
# In this case, a decision tree is used due to the multiple predictors present, which are easier to distinguish and visualise by using this method than with a KNN model. Considering the potential use of this tree for non-mathematicians to determine potential infectiousness from Smallpox, a tree is easier to interpret and follow than several KNN-modelled graphs (this is partially due to the several predictors, which would require multiple visualisations using KNN). A decision tree also determines the best predictors to use at each node, creating the near optimal decision pathways. It does not, however, reach a globally optimal solution due to the constraint of overfitting.
#
# Training data will be used in this case to set parameters for decisions at each decision node, and testing data will allow these to be changed based on the outcomes of each iteration. A balance must be found between training data accuracy, and the potential for overfitting of data. Overfitting can be caused by trees which have a large depth, too many decision nodes, or too many leaf nodes. These factors can lead to the formation of a tree which fits the training data for the disease too well, leading to the possible failure to predict future diagnoses of Smallpox, as decisions are based solely on a restricted set of data points. Consequently, a depth of 3 is used to avoid overfitting. A minimum lead node sample size of 1 is used in this case as this finds the most optimal testing data accuracy, potentially due to the small sample size.
#
# In this case, a solution very close to, but not at, the global optimum is reached, with a test accuracy score of 0.95. This is a cause of the decision nodes being locally greedy, meaning that binary splits are made without the consideration of the entire solution. Consequently, a local optima is achieved.

# %%
#implementation of decision tree
#import packages
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

df = pd.read_csv('CS51_Assignment_Diagnosis_Data (1).csv') #import data

all_inputs = df[['Temperature', 'WBC Count', 'Headache Severity', 'Cough Severity']].values #array of values
all_classes = df[ 'Infected'].values #array of values

def accuracy(n): #simulations to calculate averages for training and testing accuracies with different data splits
    train_array = [] #for training accuracy values
    test_array = [] #for testing acccuracy values
    for i in range(n): #loop to run simulations
        (train_inputs, test_inputs, train_classes, test_classes) = train_test_split(all_inputs, all_classes, train_size=0.7, test_size=0.3,random_state=1)
        #randomise data into training and testing groups 
        dtc = DecisionTreeClassifier(max_depth = 3, min_samples_leaf = 1) #create boundaries to split data in decision tree
        dtc.fit(train_inputs, train_classes) #fit training data into decision tree leaf nodes
        train_array.append(dtc.score(train_inputs, train_classes)) #append accuracy of tree for training data
        test_array.append(dtc.score(test_inputs, test_classes)) #append accuracy of tree for testing data
    train_avg = sum(train_array) / n #avg training accuracy
    test_avg = sum(test_array) / n #avg testing accuracy
    return train_avg, test_avg #output averages

average_accuracies = accuracy(1000) #call function to run simulations
print("Training Accuracy score:", average_accuracies[0]) #print training accuracy
print("Test Accuracy score:", average_accuracies[1]) #print testing accuracy
plt.figure(figsize = (15, 10)) #increase figure size 
tree.plot_tree(dtc, feature_names = ['Temperature', 'WBC Count', 'Headache Severity', 'Cough Severity'], class_names = ['Not infected', 'Infected'], rounded = True) #plot tree
# Out:
# Training Accuracy score: 0.9857142857142722
# Test Accuracy score: 0.9493666666666595
# [Text(342.40909090909093, 475.65000000000003, 'Temperature <= 37.195\ngini = 0.5\nsamples = 70\nvalue = [36, 34]\nclass = Not infected'),
#  Text(152.1818181818182, 339.75, 'WBC Count <= 16310.63\ngini = 0.061\nsamples = 32\nvalue = [31, 1]\nclass = Not infected'),
#  Text(76.0909090909091, 203.85000000000002, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]\nclass = Not infected'),
#  Text(228.27272727272728, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Infected'),
#  Text(532.6363636363636, 339.75, 'WBC Count <= 8716.965\ngini = 0.229\nsamples = 38\nvalue = [5, 33]\nclass = Infected'),
#  Text(380.4545454545455, 203.85000000000002, 'Headache Severity <= 5.28\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Not infected'),
#  Text(304.3636363636364, 67.94999999999999, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not infected'),
# ...

# %% [markdown]
# ## **PART 2: SIMULATION**
#
# The SIR model of the spread of disease is commonly used to help understand how a disease might move through a population. You were introduced to this with the NetLogo agent-based model in NS50 and will review it again in Week 7 of CS51. Check out the class readings to learn about this model.
#
#
# For this assignment, you will select one disease of your choice to model. Please choose a disease from [THIS LIST](https://docs.google.com/spreadsheets/d/1_p_6W8Zh07XFwuQ3EzkT7PEdbtwTzejHbpKm_wBOLas/edit?usp=sharing) to investigate.  If you would like to select your own disease to model, you may email your professor with the disease and parameter descriptions for approval. You must select an infectious disease (one that is transmitted from person to person through a viral, bacterial, or parasitic agent), not a genetic or environmental disease.
#
# ### **Part 2.1 Numerical Modeling and Simulation**
#
# For this part of the assignment, you’ll consider the SIR model described by the set of differential equations below, and the numerical simulation in Python via Euler’s method.
#
# $$ \frac{dS}{dt} = -\frac{b}{N}S(t) I(t) $$
# <br>
# $$ \frac{dI}{dt} = \frac{b}{N}S(t)I(t) - kI(t) $$
# <br>
# $$ \frac{dR}{dt} = k I(t) $$
# <br>
#
# #### 2.1.1 Variables and Parameters (~250 words) [#variables]
#
# This section serves to set up an initial analysis of the SIR model.
# 1. State the disease you selected to model.
# 2. Identify the relevant **variables** of the model, classify what type of variables they are, and explain what they mean in the context of your model.
# 3. Explain what the relevant **parameters** ($b$ and $k$) are and how to select appropriate values for them, including the initial values. You’re encouraged to use empirical data if possible to justify these values. You may also complete a well-reasoned #estimation for any values that are difficult to justify with empirical data. Include APA citations for any external sources used. Note that you can work with population values $S$, $I$, $R$, or proportions, $S/N$, $I/N$, $R/N$, as long as you are consistent.
# 4. Explain what it would mean for the parameters ($b$ and $k$) to be smaller or larger. Consider what real-world factors would reduce or increase these parameters.
# 5. *Optional*: Modify the basic SIR model to add a layer of real-world complexity. A few ideas are listed below. Explain the key features of the extended model, including the modified differential equations and a full description and classification of any new variables and parameters following the steps above.
#   - Vaccination
#   - Antibiotic use and/or development of antibiotic resistance
#   - Variability in population susceptibility (e.g. children and the elderly have different rates of infection compared to young adults).
#   - Birth and death rates in the population

# %% [markdown]
# The investigation of the spread of Smallpox in the United Kingdom will include t, a continuous quantitative variable that represents the time over which the spread of the disease will be measured, however here will be used as a discrete variable due to the steps in time required to use Euler's method. This is the independent variable, and S, I, R, and D (representing deaths), dependent variables. S, I, R, and D, discrete quantitative variables, respectively represent the number of individuals who could possibly contract Smallpox, those who are infected, those who have recovered, and those who have died from the disease. Confounding variables that need to be accounted for when interpreting the spread of Smallpox include age, gender, race, healthcare accessibility, and location, as well as preventative measures such as social distancing, isolation, and mask-wearing, that can mostly be confounded in this situation through policy implementation by governments.
#
# Parameters b, k, d, and v define our model for the spread of Smallpox, and are predetermined before running simulations. The parameter b represents infection rate, in this case 0.5, the number of susceptible individuals who will become infected with smallpox (the number of individuals who don't have smallpox who come into contact with those who are currently infected, multiplied by the probability of contracting the disease when coming into contact with an infected individual). The parameter k represents the recovery rate, in this case 0.086, the number of infected individuals who will recover from smallpox (the reciprocal of the infection period). Parameter d represents the death rate (the proportion of individuals who will die from Smallpox), and v the vaccination rate (the proportion of susceptible individuals who will be vaccinated each day).
#
# An increase in the value of b (through the minimization of prevention techniques such as masks and social distancing, and increased contact through events such as concerts) would lead to a sharper increase in the number of individuals who have smallpox, and therefore a decrease in the number of individuals susceptible to the disease. An increase in the value of k (through medicine, and decreased viral load to begin with which would be through measures such as social distancing and masks) would lead to a less sharp increase in the number of individuals who have smallpox as individuals are infectious for less time, therefore there are fewer individuals that are infectious at any one point.

# %% [markdown]
# #### 2.1.2 Euler’s Method Description (~150 words) [#algorithms]
#
# Explain what it means to solve the SIR differential equations and how Euler’s method works as an algorithm to achieve a numerical solution via simulation. In your explanation, identify whether the model and simulation are continuous or discrete, and consider the role of the step size (`h`) in the algorithm.

# %% [markdown]
# To solve the SIR equations means to determine the set of mathematical functions S(t), I(t), R(t) which allow us to see the numbers of individuals who are susceptible, infected and recovered from Smallpox over time, based on the preset parameters of infection and recovery rates, b and k.
#
# To model the spread of Smallpox, I have used two extra parameters, d and v, to produce differential equations to model the deaths from Smallpox, as well as the number of vaccinated individuals over time after the vaccine has been produced:
#
# $$ \frac{dS}{dt} = -\frac{b}{N}S(t) I(t) - v S(t) $$
# <br>
# $$ \frac{dI}{dt} = \frac{b}{N}S(t)I(t) - kI(t) $$
# <br>
# $$ \frac{dR}{dt} = (1-d) k I(t) $$
# <br>
# $$ \frac{dD}{dt} = d k I(t) $$
# <br>
# $$ \frac{dV}{dt} = v S(t) $$
# <br>
#
# Euler's method allows us to numerically solve these equations, to produce graphs of S, I, R, D, and V over time through approximations. Using an initial point with the given differential equations for the SIR model, subsequent points can be predicted, each using the co-ordinates of the previous point and the tangent at the given x-value to find the next point.
#
# Euler's method provides a discrete approximation to a continuous-time system as the state variables, S, I, R, D, and V only change at a set number of points over time.
#
# Smaller step sizes (h) can be used to increase the accuracy of the model by reducing the aggregate error which increases with each additional point in the model. However, this increases the computer power required to find the solution, therefore it can be necessary to find a balance between these two factors. The use of Euler's method allows us to find a very close approximation to the analytical solution by using a small step value, and without having to solve differential equations.

# %% [markdown]
# #### 2.1.3 Euler’s Method Implementation [#algorithms, #dataviz]
#
# Implement a numerical simulation to derive the implications of your model using Euler’s method in Python.Your simulation must generate at least one relevant visualization of the disease dynamics, including a descriptive figure legend and caption. You may need to adjust the run-time and step size in your simulation to ensure the visualization is maximally informative. Include thorough comments in your code to convey your understanding of the implementation of Euler’s method.

# %%
#import packages
import numpy as np 
import matplotlib.pyplot as plt

t0 = 0 #starting value for t
t1 = 120 #ending value for t

h = 1 #step size
steps = int((t1 - t0)/h + 1) #number of steps

t = np.linspace(t0, t1, steps) #storing t values
S = np.zeros(steps) #for storing S values
I = np.zeros(steps) #for storing I values
R = np.zeros(steps) #for storing R values
D = np.zeros(steps) #for storing D values
V = np.zeros(steps) #for storing V values

b = 0.5 #infection rate
k = 0.15 #recovery rate
d = 0.3 #death rate (Signs and Symptoms, 2021)
v = 0.05 #vaccination rate, 5% (number of individuals vaccinated per unit t)

def dSdt(t, S, I): #function for susceptible individuals 
    if t > 40: #after vaccine
        return (-b / N) * S * I - v * S #return number of individuals susceptible at time t after vaccine
    else: #before vaccine
        return (-b / N) * S * I #return number of individuals susceptible at time t before vaccine

def dIdt(t, S, I): #function for infected individual 
    return ((b / N) * S * I) - (k * I) #return number of individuals infected at time t

def dRdt(t, I): #function for recovered individuals
    return (1 - d) * (k * I) #return number of individuals recovered at time t

def dDdt(t, I): #function for dead individuals
    return d * (k * I) #return number of dead individuals at time t

def dVdt(t, S): #function for vaccinated individuals
    if t > 40: #after vaccine
        return v * S #return number of vaccinated individuals per day
    else: #before vaccine
        return 0 #none vaccinated before vaccine invented

S[0] = 56180000 #initial susceptible individuals, population of UK (United Kingdom  - Place Explorer - Data Commons, 2021)
I[0] = 1 #initial infected individuals, initial carrier of Smallpox to the UK
R[0] = 0 #initial recovered individuals
D[0] = 0 #intitial deceased individuals 
V[0] = 0 #initial vaccinated individuals
N = S[0] + I[0] + R[0] + D[0] + V[0] #total individuals in system = sum of variables

for n in range(steps-1): #steps through points in time 
    S[n+1] = S[n] + dSdt(t[n],S[n],I[n]) #adds next cumulative susceptible count to array
    I[n+1] = I[n] + dIdt(t[n],S[n],I[n]) #adds next cumulative infected count to array
    R[n+1] = R[n] + dRdt(t[n], I[n]) #adds next cumulative recovered count to array
    D[n+1] = D[n] + dDdt(t[n], I[n]) #adds next cumulative dead count to array
    V[n+1] = V[n] + dVdt(t[n], S[n]) #adds next cumulative vaccinated count to array

plt.rcParams.update({'font.size': 15}) #set font size
plt.rcParams["figure.figsize"] = [8,5] #set figure size
plt.plot(t,S,linewidth=2,label='S(t)') #plot cumulative susceptible over time
plt.plot(t,I,linewidth=2,label='I(t)') #plot cumulative infected over time
plt.plot(t,R,linewidth=2,label='R(t)') #plot cumulative recovered over time
plt.plot(t,D,linewidth=2,label='D(t)') #plot cumulative dead over time
plt.plot(t,V,linewidth=2,label='V(t)') #plot cumulative vaccinated over time
plt.xlabel('Time (days)', fontsize = 8) #label x axis
plt.ylabel('Number of individuals (10s of millions)', fontsize = 8) #label y axis
plt.title('Number of Individuals in S, I, R, D, and V Over Time', fontsize = 14) #set title
plt.legend(loc = 'best') #place legend on graph in optimal place
plt.show() #display graph

# %% [markdown]
# #### 2.1.4 Results and Interpretation (~250 words) [#modeling, #dataviz]
#
# - Interpret the results of the numerical simulation by making reference the output in the visualization(s). To fully interpret the results, you should run the simulation multiple times with varying parameter inputs (b and k) and observe the behavior of your model. Does the behavior align with what you would expect these adjustments to have in reality (given your answer to 1.4 above)?
#
# - Explain how useful this model is by considering the following guiding questions: What insights can be gained? How closely do the results match what you’d expect in reality? What are the most notable assumptions of this model and what impact do they have on its usefulness?

# %% [markdown]
# Using the value of 0.5 for infection rate, and 0.086 for recovery rate, the graph shows a steady increase in the number of infected individuals to a peak on the ~55th day after the first individual in the population became infected with Smallpox. The number of susceptible individuals rapidly decreases in this time, and there is a slight increase in those who have recovered from the disease. After this point in time, the number of infected individuals decreases slowly from its peak, reaching the point where no individuals have Smallpox, and everyone has recovered, dead, or been vaccinated at ~day 110.
#
# Increasing the infection rate (b) to 0.8 (with k as 0.086) produces a graph that appears similar to the first scenario, but with a sharper increase in the number of infected agents, reaching a peak at ~day 35, almost twice as fast as the first scenario. This is in line with what would be expected, as the increase in infection rate (caused by a greater number of interactions between agents and/or a greater probability of contracting Smallpox given that an interaction with an infected individual has taken place) causes a more rapid increase in individuals who were susceptible contracting the disease. In this case, Smallpox is eliminated from the population at a faster rate, all agents being recovered, died, or been vaccinated at ~day 60 in the simulation.
#
# Increasing the recovery rate (k) to 0.15 (with b as 0.5) produces a much lower peak at ~day 60 which is much lower than the initial simulation at ~4 million individuals, and a much faster elimination of the infection at ~day 80. In this case, not all individuals within the population will contract Smallpox, as not all susceptible individuals will come into contact with infected agents, and those who do may not pick up the virus. Furthermore, it allows for more agents to be vaccinated before becoming infected with the disease, removing them from the number of susceptible individuals.
#
# The final simulation (displayed above) is more akin to what we may observe in reality, as improvements in medicine over the course of a pandemic often lead to an increase in recovery rate. Therefore it is unprobable that every individual in the population will contract the disease. Moreover, the proportion of the population who contract Smallpox in this simulation is lower (yet still greater than the actual numbers), and the proportion of vaccinated individuals is higher (closer to the number of vaccinated people in reality).
#
# Running this model with many different values of parameters b and k can help to determine the effect of different preventative measures for the spread of Smallpox. Multiple simulations can help to find a balance between inhibiting the spread of Smallpox, and other factors. For example, the closure of museums can minimise contact between individuals, reducing the value of b, however this could also lead to a decrease in tourism, and therefore economic hardship for certain countries. Governments can therefore use this information to make decisions which provide a balance between such factors.
#
# This model is not, however, fully accurate to that which was observed throughout history in the UK, as it does not model preventative measures put in place to mitigate the spread of disease, reducing the value of infection rate such as isolation, which was strongly used in the 1978 outbreak to inhibit the spread (Krylova & Earn, 2019). It also doesn't account for the changes in values of S, I, R, D, and V that result from modelling humans as a complex system with unpredictable behaviours, as there is no random element to this deterministic model.

# %% [markdown]
# ### **Part 2.2 Agent-Based Modeling and Simulation**
#
# For this part of the assignment, you’ll consider an agent-based model to describe the spread of disease and an agent-based simulation implemented in [NetLogo](http://ccl.northwestern.edu/netlogo/models/Virus). Explore the model thoroughly and run it multiple times with different parameter settings.
#
# Note about parameters: this model uses similar variables and parameters as the one above, but the parameters are not defined identically. In particular, the "Infectiousness" parameter in NetLogo is analogous to, but not equivalent to the infection rate in the SIR model. Thus, they should not be set to the same value in both of your simulations. The infection rate in the SIR model already incorporates the interaction rate of individuals, while the NetLogo simulation sets that rate separately. In other words, the "infectiousness" parameter in NetLogo only dictates the probability of infecting someone if they come close enough, but does not take into account how frequent those interactions occur. Be sure to investigate the meaning of the other parameters as well so that you understand how to set them appropriately.
# <br>
#
# #### 2.2.1 Simulation Comparison (~250 words) [#modeling]
#
# After fully exploring the model and running multiple simulations, summarize how it compares to your simulation above. Address the following points:
#
# - Identify the main similarities between the Python SIR simulation and the NetLogo simulation.
#
# - Identify the major differences between the Python SIR simulation and the NetLogo simulation.
#
# - Identify one advantage of the Python SIR simulation over the NetLogo simulation.
#
# - Identify one advantage of the NetLogo simulation over the Python SIR simulation.
#
# - Based on the results of the simulations, which one do you believe is a more realistic representation of nature? Justify your reasoning.

# %% [markdown]
# Similar parameters are used for both the SIR model and NetLogo agent-based model. Both use infection and recovery rates however they are defined by different factors in the two different models. When considering the levels at which you may observe the spread of disease in both cases, the NetLogo model allows you to see individual agents, and the impact they have on each other. In this way ABM uses a much more bottom-up approach, which can be more useful for situations in which the interactions between individuals are necessary to consider, such as looking at the existence of central locations which many agents visit (eg. supermarkets), or looking at the network structures which contribute to the spread of disease. The SIR model, on the other hand, looks at a top-down scenario, in which the overall spread of disease within a population can be determined. This approach can be more useful for the implementation of policy surrounding preventative measures, or to determine the impact of a pandemic on other systems. ABM also models the spread of Smallpox as a heterogeneous system, in which individuals can display different characteristics, whereas SIR always looks at the entire system as homogenous. The NetLogo model also uses a random variable to model the spread of Smallpox, creating a stochastic model in which the randomness of individuals is accounted for. The SIR model, on the other hand, is a deterministic model that will produce the same results with every simulation, given that the same parameters are used each time.
#
# An advantage of the SIR model is that it requires less computational power to implement, allowing you to quickly model the potential spread of a disease over time. This is especially useful when constraints such as time and money apply. A major advantage of the NetLogo ABM model is that a distribution of outcomes for each set of parameters can be determined (using the stochastic variable), which allows individuals and governments to implement policy based on possible worst-case scenarios, to better prevent and mitigate outbreaks of the disease.
#
# I believe that the NetLogo model better represents the spread of disease as it would occur in reality due to the heterogenity of indiviudals, which allows for differences between indiviudals. Furthermore, the use of a random variable accounts for the unpredictability of humans who operate within a network. Interactions between individuals create emergent properties within populations, often producing unexpected behaviors. Although the NetLogo ABM model does not exactly determine the effect of specific emergent properties, it can be run multiple times to produce some potential bounds for the progression of disease using the stochastic variable.

# %% [markdown]
# #### 2.2.2 *Optional*: Your own agent-based simulation [#algorithms, #modeling]:
#
# Create your own agent-based simulation of the disease dynamics for your chosen disease in Python. You may add in real-world complexities as desired (vaccination, antibiotic use and/or development of antibiotic resistance, variability in population susceptibility). Your work needs to be explained in sufficient detail, including citations to any external sources consulted, in order to receive credit.
#
# - One option: a tree graph can be useful in modeling person-to-person interactions.
#
# - Another option: turtles.

# %%
#import packages
import networkx as nx
import EoN
import matplotlib.pyplot as plt
from collections import defaultdict

G = nx.grid_2d_graph(100,100) #each node is (u,v) where 0<=u,v<=99, creates 100x100 grid of agents
initial_infections = [(u,v) for (u,v) in G if 45<u<55 and 45<v<55] #agents that are initially infected

H = nx.DiGraph() #the spontaneous transitions
H.add_edge('Sus', 'Vac', rate = 0.01) #vaccination rate
H.add_edge('Inf', 'Rec', rate = 1.0) #rate of individuals that will recover from being infected

J = nx.DiGraph() #the induced transitions
J.add_edge(('Inf', 'Sus'), ('Inf', 'Inf'), rate = 2.0) #rate of people that become infected from susceptible

IC = defaultdict(lambda:'Sus') #set all initial agents (co-ordinates) to susceptible
for node in initial_infections: #loop through initially infected nodes
    IC[node] = 'Inf' #set initial infected nodes to infected from susceptible
    
return_statuses = ['Sus', 'Inf', 'Rec', 'Vac'] #determine numbers of each group

color_dict = {'Sus': 'white','Inf':'red', 'Rec':'green','Vac': 'blue'} #change colours of agents
pos = {node:node for node in G} #cycles through grid of agents for co-ordinates
tex = False #eliminate italics
sim_kwargs = {'color_dict':color_dict, 'pos':pos, 'tex':tex} #set simulation parameters

sim = EoN.Gillespie_simple_contagion(G, H, J, IC, return_statuses, tmax=30,
return_full_data=True, sim_kwargs=sim_kwargs) #run simulation returning data, using set parameters

sim.display(time=8, node_size = 4, ts_plots=[['Inf']]) #set display parameters and variables (time run, size of agents, plots to make)
plt.xlabel('Time (days)') #set x axis label
plt.ylabel('Number of individuals') #set y axis label
plt.title('Number of Infected Individuals Over Time') #set title
plt.tight_layout() #to prevent overlapping of figures
plt.show() #display figures

# %% [markdown]
# ## **REFLECTION**
#
# In less than 100 words, explain how this unit has enhanced your view of the power of modeling, algorithms, and simulations to describe the natural world around you.

# %% [markdown]
# I now understand how useful modelling can be in the process of policy-making for governments. The use of such models allows us to predict potential progressions of disease to minimise their negative impacts on society. Multiple varying simulations using ranges of parameters can be used in conjunction to provide bounds for different variables over time, helping to determine the best and worst-case scenarios of the spread of a disease. Past events can also be used to help test the validity of models, and to provide insight into the nature and volume of interactions between humans to improve models.

# %% [markdown]
# ## **References**

# %% [markdown]
# Assignment Data Scatter Plot Matrix.png. (2021). Assignment Data Scatter Plot Matrix.png. Google Docs. https://drive.google.com/file/d/1td_jCTzYiOCMPJ8CwVSJU7u-pQ-5R1JW/view
#
# Data Commons. (2021). United Kingdom  - Place Explorer -Data Commons. Datacommons.org.
# https://datacommons.org/place/country/GBR?utm_medium=explore&mprop=count&popt=Person&hl=en
#
# Division of High Consequence Pathogens and Pathology. (2021). Signs and Symptoms. Centers for Disease Control and Prevention. https://www.cdc.gov/smallpox/symptoms/index.htmlKrylova,
#
# O., & Earn, D. J. D. (2019). Patterns of smallpox mortality in London, England, over three centuries.
# https://doi.org/10.1101/771220
#
# Scikit-Learn. (2020). sklearn.tree.DecisionTreeClassifier — scikit-learn 0.24.1 documentation. Scikit-Learn.org.
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
#
# View more posts. (2020, June 7). Understanding Agent Based Model with Python. Data Science Chalk Talk; Data Science Chalk Talk. https://datasciencechalktalk.com/2020/06/07/understanding-agent-based-model-with-python/

# %% [markdown]
# ## You're done!
#
# You must upload TWO files:
#
#
# 1. A **PDF** of your entire assignment. This is to be submitted as a separate file, NOT simply inside the zipped folder. Email attachments will not be accepted. We encourage students to follow the tips available in [this guide](https://docs.google.com/document/d/1gRMol9Ebbvyu1mvEKzma92o_N7ZbNXsPIb1QdQV0TeE/edit?usp=sharing), especially the best practices listed at the end.
#
#
# 2. A **zipped folder** containing the .ipynb file and any other relevant files for running the notebook.
